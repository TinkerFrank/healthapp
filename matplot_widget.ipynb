# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import TextBox
# %matplotlib widget

# %% [markdown]
# > pip install  ipympl

# %%
fig, ax = plt.subplots()
fig.subplots_adjust(bottom=0.2)

x = np.arange(-25.0, 25.0, 0.001)
l, = ax.plot(x, np.zeros_like(x), color='red', lw=3)

def submit(expression):
    """
    Update the plotted function to the new math *expression*.
    """
    ydata = eval(expression)
    l.set_ydata(ydata)
    ax.relim()
    ax.autoscale_view()
    plt.draw()

axbox = fig.add_axes([0.1, 0.05, 0.8, 0.075])
text_box = TextBox(axbox, "Evaluate", textalignment="center")
text_box.on_submit(submit)
text_box.set_val("x")  # Trigger `submit` with the initial string.
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File d:\0_Program_Files\Python3.10.1\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\backends\backend_webagg_core.py:462, in FigureManagerWebAgg.handle_json(self, content)
#     461 def handle_json(self, content):
# --> 462     self.canvas.handle_event(content)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\backends\backend_webagg_core.py:266, in FigureCanvasWebAggCore.handle_event(self, event)
#     263 e_type = event['type']
#     264 handler = getattr(self, 'handle_{0}'.format(e_type),
#     265                   self.handle_unknown_event)
# --> 266 return handler(event)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\backends\backend_webagg_core.py:317, in FigureCanvasWebAggCore._handle_key(self, event)
#     314 def _handle_key(self, event):
#     315     KeyEvent(event['type'] + '_event', self,
#     316              _handle_key(event['key']), *self._last_mouse_xy,
# --> 317              guiEvent=event.get('guiEvent'))._process()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\backend_bases.py:1259, in Event._process(self)
#    1257 def _process(self):
#    1258     """Generate an event with name ``self.name`` on ``self.canvas``."""
# -> 1259     self.canvas.callbacks.process(self.name, self)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:309, in CallbackRegistry.process(self, s, *args, **kwargs)
#     307 except Exception as exc:
#     308     if self.exception_handler is not None:
# --> 309         self.exception_handler(exc)
#     310     else:
#     311         raise
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:96, in _exception_printer(exc)
#      94 def _exception_printer(exc):
#      95     if _get_running_interactive_framework() in ["headless", None]:
# ---> 96         raise exc
#      97     else:
#      98         traceback.print_exc()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:304, in CallbackRegistry.process(self, s, *args, **kwargs)
#     302 if func is not None:
#     303     try:
# --> 304         func(*args, **kwargs)
#     305     # this does not capture KeyboardInterrupt, SystemExit,
#     306     # and GeneratorExit
#     307     except Exception as exc:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\widgets.py:1497, in TextBox._keypress(self, event)
#    1495 self._observers.process('change', self.text)
#    1496 if key in ["enter", "return"]:
# -> 1497     self._observers.process('submit', self.text)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:309, in CallbackRegistry.process(self, s, *args, **kwargs)
#     307 except Exception as exc:
#     308     if self.exception_handler is not None:
# --> 309         self.exception_handler(exc)
#     310     else:
#     311         raise
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:96, in _exception_printer(exc)
#      94 def _exception_printer(exc):
#      95     if _get_running_interactive_framework() in ["headless", None]:
# ---> 96         raise exc
#      97     else:
#      98         traceback.print_exc()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:304, in CallbackRegistry.process(self, s, *args, **kwargs)
#     302 if func is not None:
#     303     try:
# --> 304         func(*args, **kwargs)
#     305     # this does not capture KeyboardInterrupt, SystemExit,
#     306     # and GeneratorExit
#     307     except Exception as exc:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\widgets.py:1588, in TextBox.on_submit.<locals>.<lambda>(text)
#    1581 def on_submit(self, func):
#    1582     """
#    1583     When the user hits enter or leaves the submission box, call this
#    1584     *func* with event.
#    1585
#    1586     A connection id is returned which can be used to disconnect.
#    1587     """
# -> 1588     return self._observers.connect('submit', lambda text: func(text))
#
# d:\.MedProject\healthapp\matplot_widget.ipynb Cell 3 in 1
#       <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> def submit(expression):
#       <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a>     """
#       <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a>     Update the plotted function to the new math *expression*.
#      <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a>     """
# ---> <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a>     ydata = eval(expression)
#      <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a>     l.set_ydata(ydata)
#      <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a>     ax.relim()
#
# File <string>:1
#
# NameError: name 'sin' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File d:\0_Program_Files\Python3.10.1\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\backends\backend_webagg_core.py:462, in FigureManagerWebAgg.handle_json(self, content)
#     461 def handle_json(self, content):
# --> 462     self.canvas.handle_event(content)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\backends\backend_webagg_core.py:266, in FigureCanvasWebAggCore.handle_event(self, event)
#     263 e_type = event['type']
#     264 handler = getattr(self, 'handle_{0}'.format(e_type),
#     265                   self.handle_unknown_event)
# --> 266 return handler(event)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\backends\backend_webagg_core.py:317, in FigureCanvasWebAggCore._handle_key(self, event)
#     314 def _handle_key(self, event):
#     315     KeyEvent(event['type'] + '_event', self,
#     316              _handle_key(event['key']), *self._last_mouse_xy,
# --> 317              guiEvent=event.get('guiEvent'))._process()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\backend_bases.py:1259, in Event._process(self)
#    1257 def _process(self):
#    1258     """Generate an event with name ``self.name`` on ``self.canvas``."""
# -> 1259     self.canvas.callbacks.process(self.name, self)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:309, in CallbackRegistry.process(self, s, *args, **kwargs)
#     307 except Exception as exc:
#     308     if self.exception_handler is not None:
# --> 309         self.exception_handler(exc)
#     310     else:
#     311         raise
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:96, in _exception_printer(exc)
#      94 def _exception_printer(exc):
#      95     if _get_running_interactive_framework() in ["headless", None]:
# ---> 96         raise exc
#      97     else:
#      98         traceback.print_exc()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:304, in CallbackRegistry.process(self, s, *args, **kwargs)
#     302 if func is not None:
#     303     try:
# --> 304         func(*args, **kwargs)
#     305     # this does not capture KeyboardInterrupt, SystemExit,
#     306     # and GeneratorExit
#     307     except Exception as exc:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\widgets.py:1497, in TextBox._keypress(self, event)
#    1495 self._observers.process('change', self.text)
#    1496 if key in ["enter", "return"]:
# -> 1497     self._observers.process('submit', self.text)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:309, in CallbackRegistry.process(self, s, *args, **kwargs)
#     307 except Exception as exc:
#     308     if self.exception_handler is not None:
# --> 309         self.exception_handler(exc)
#     310     else:
#     311         raise
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:96, in _exception_printer(exc)
#      94 def _exception_printer(exc):
#      95     if _get_running_interactive_framework() in ["headless", None]:
# ---> 96         raise exc
#      97     else:
#      98         traceback.print_exc()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:304, in CallbackRegistry.process(self, s, *args, **kwargs)
#     302 if func is not None:
#     303     try:
# --> 304         func(*args, **kwargs)
#     305     # this does not capture KeyboardInterrupt, SystemExit,
#     306     # and GeneratorExit
#     307     except Exception as exc:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\widgets.py:1588, in TextBox.on_submit.<locals>.<lambda>(text)
#    1581 def on_submit(self, func):
#    1582     """
#    1583     When the user hits enter or leaves the submission box, call this
#    1584     *func* with event.
#    1585
#    1586     A connection id is returned which can be used to disconnect.
#    1587     """
# -> 1588     return self._observers.connect('submit', lambda text: func(text))
#
# d:\.MedProject\healthapp\matplot_widget.ipynb Cell 3 in 1
#       <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> def submit(expression):
#       <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a>     """
#       <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a>     Update the plotted function to the new math *expression*.
#      <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a>     """
# ---> <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a>     ydata = eval(expression)
#      <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a>     l.set_ydata(ydata)
#      <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a>     ax.relim()
#
# File <string>:1
#
# NameError: name 'sin' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File d:\0_Program_Files\Python3.10.1\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\backends\backend_webagg_core.py:462, in FigureManagerWebAgg.handle_json(self, content)
#     461 def handle_json(self, content):
# --> 462     self.canvas.handle_event(content)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\backends\backend_webagg_core.py:266, in FigureCanvasWebAggCore.handle_event(self, event)
#     263 e_type = event['type']
#     264 handler = getattr(self, 'handle_{0}'.format(e_type),
#     265                   self.handle_unknown_event)
# --> 266 return handler(event)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\backends\backend_webagg_core.py:317, in FigureCanvasWebAggCore._handle_key(self, event)
#     314 def _handle_key(self, event):
#     315     KeyEvent(event['type'] + '_event', self,
#     316              _handle_key(event['key']), *self._last_mouse_xy,
# --> 317              guiEvent=event.get('guiEvent'))._process()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\backend_bases.py:1259, in Event._process(self)
#    1257 def _process(self):
#    1258     """Generate an event with name ``self.name`` on ``self.canvas``."""
# -> 1259     self.canvas.callbacks.process(self.name, self)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:309, in CallbackRegistry.process(self, s, *args, **kwargs)
#     307 except Exception as exc:
#     308     if self.exception_handler is not None:
# --> 309         self.exception_handler(exc)
#     310     else:
#     311         raise
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:96, in _exception_printer(exc)
#      94 def _exception_printer(exc):
#      95     if _get_running_interactive_framework() in ["headless", None]:
# ---> 96         raise exc
#      97     else:
#      98         traceback.print_exc()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:304, in CallbackRegistry.process(self, s, *args, **kwargs)
#     302 if func is not None:
#     303     try:
# --> 304         func(*args, **kwargs)
#     305     # this does not capture KeyboardInterrupt, SystemExit,
#     306     # and GeneratorExit
#     307     except Exception as exc:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\widgets.py:1497, in TextBox._keypress(self, event)
#    1495 self._observers.process('change', self.text)
#    1496 if key in ["enter", "return"]:
# -> 1497     self._observers.process('submit', self.text)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:309, in CallbackRegistry.process(self, s, *args, **kwargs)
#     307 except Exception as exc:
#     308     if self.exception_handler is not None:
# --> 309         self.exception_handler(exc)
#     310     else:
#     311         raise
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:96, in _exception_printer(exc)
#      94 def _exception_printer(exc):
#      95     if _get_running_interactive_framework() in ["headless", None]:
# ---> 96         raise exc
#      97     else:
#      98         traceback.print_exc()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:304, in CallbackRegistry.process(self, s, *args, **kwargs)
#     302 if func is not None:
#     303     try:
# --> 304         func(*args, **kwargs)
#     305     # this does not capture KeyboardInterrupt, SystemExit,
#     306     # and GeneratorExit
#     307     except Exception as exc:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\widgets.py:1588, in TextBox.on_submit.<locals>.<lambda>(text)
#    1581 def on_submit(self, func):
#    1582     """
#    1583     When the user hits enter or leaves the submission box, call this
#    1584     *func* with event.
#    1585
#    1586     A connection id is returned which can be used to disconnect.
#    1587     """
# -> 1588     return self._observers.connect('submit', lambda text: func(text))
#
# d:\.MedProject\healthapp\matplot_widget.ipynb Cell 3 in 1
#       <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> def submit(expression):
#       <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a>     """
#       <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a>     Update the plotted function to the new math *expression*.
#      <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a>     """
# ---> <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a>     ydata = eval(expression)
#      <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a>     l.set_ydata(ydata)
#      <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a>     ax.relim()
#
# File <string>:1
#
# NameError: name 'sin' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File d:\0_Program_Files\Python3.10.1\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\backends\backend_webagg_core.py:462, in FigureManagerWebAgg.handle_json(self, content)
#     461 def handle_json(self, content):
# --> 462     self.canvas.handle_event(content)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\backends\backend_webagg_core.py:266, in FigureCanvasWebAggCore.handle_event(self, event)
#     263 e_type = event['type']
#     264 handler = getattr(self, 'handle_{0}'.format(e_type),
#     265                   self.handle_unknown_event)
# --> 266 return handler(event)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\backends\backend_webagg_core.py:317, in FigureCanvasWebAggCore._handle_key(self, event)
#     314 def _handle_key(self, event):
#     315     KeyEvent(event['type'] + '_event', self,
#     316              _handle_key(event['key']), *self._last_mouse_xy,
# --> 317              guiEvent=event.get('guiEvent'))._process()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\backend_bases.py:1259, in Event._process(self)
#    1257 def _process(self):
#    1258     """Generate an event with name ``self.name`` on ``self.canvas``."""
# -> 1259     self.canvas.callbacks.process(self.name, self)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:309, in CallbackRegistry.process(self, s, *args, **kwargs)
#     307 except Exception as exc:
#     308     if self.exception_handler is not None:
# --> 309         self.exception_handler(exc)
#     310     else:
#     311         raise
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:96, in _exception_printer(exc)
#      94 def _exception_printer(exc):
#      95     if _get_running_interactive_framework() in ["headless", None]:
# ---> 96         raise exc
#      97     else:
#      98         traceback.print_exc()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:304, in CallbackRegistry.process(self, s, *args, **kwargs)
#     302 if func is not None:
#     303     try:
# --> 304         func(*args, **kwargs)
#     305     # this does not capture KeyboardInterrupt, SystemExit,
#     306     # and GeneratorExit
#     307     except Exception as exc:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\widgets.py:1497, in TextBox._keypress(self, event)
#    1495 self._observers.process('change', self.text)
#    1496 if key in ["enter", "return"]:
# -> 1497     self._observers.process('submit', self.text)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:309, in CallbackRegistry.process(self, s, *args, **kwargs)
#     307 except Exception as exc:
#     308     if self.exception_handler is not None:
# --> 309         self.exception_handler(exc)
#     310     else:
#     311         raise
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:96, in _exception_printer(exc)
#      94 def _exception_printer(exc):
#      95     if _get_running_interactive_framework() in ["headless", None]:
# ---> 96         raise exc
#      97     else:
#      98         traceback.print_exc()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:304, in CallbackRegistry.process(self, s, *args, **kwargs)
#     302 if func is not None:
#     303     try:
# --> 304         func(*args, **kwargs)
#     305     # this does not capture KeyboardInterrupt, SystemExit,
#     306     # and GeneratorExit
#     307     except Exception as exc:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\widgets.py:1588, in TextBox.on_submit.<locals>.<lambda>(text)
#    1581 def on_submit(self, func):
#    1582     """
#    1583     When the user hits enter or leaves the submission box, call this
#    1584     *func* with event.
#    1585
#    1586     A connection id is returned which can be used to disconnect.
#    1587     """
# -> 1588     return self._observers.connect('submit', lambda text: func(text))
#
# d:\.MedProject\healthapp\matplot_widget.ipynb Cell 3 in 1
#       <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> def submit(expression):
#       <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a>     """
#       <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a>     Update the plotted function to the new math *expression*.
#      <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a>     """
# ---> <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a>     ydata = eval(expression)
#      <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a>     l.set_ydata(ydata)
#      <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a>     ax.relim()
#
# File <string>:1
#
# NameError: name 'math' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File d:\0_Program_Files\Python3.10.1\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\backends\backend_webagg_core.py:462, in FigureManagerWebAgg.handle_json(self, content)
#     461 def handle_json(self, content):
# --> 462     self.canvas.handle_event(content)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\backends\backend_webagg_core.py:266, in FigureCanvasWebAggCore.handle_event(self, event)
#     263 e_type = event['type']
#     264 handler = getattr(self, 'handle_{0}'.format(e_type),
#     265                   self.handle_unknown_event)
# --> 266 return handler(event)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\backends\backend_webagg_core.py:317, in FigureCanvasWebAggCore._handle_key(self, event)
#     314 def _handle_key(self, event):
#     315     KeyEvent(event['type'] + '_event', self,
#     316              _handle_key(event['key']), *self._last_mouse_xy,
# --> 317              guiEvent=event.get('guiEvent'))._process()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\backend_bases.py:1259, in Event._process(self)
#    1257 def _process(self):
#    1258     """Generate an event with name ``self.name`` on ``self.canvas``."""
# -> 1259     self.canvas.callbacks.process(self.name, self)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:309, in CallbackRegistry.process(self, s, *args, **kwargs)
#     307 except Exception as exc:
#     308     if self.exception_handler is not None:
# --> 309         self.exception_handler(exc)
#     310     else:
#     311         raise
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:96, in _exception_printer(exc)
#      94 def _exception_printer(exc):
#      95     if _get_running_interactive_framework() in ["headless", None]:
# ---> 96         raise exc
#      97     else:
#      98         traceback.print_exc()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:304, in CallbackRegistry.process(self, s, *args, **kwargs)
#     302 if func is not None:
#     303     try:
# --> 304         func(*args, **kwargs)
#     305     # this does not capture KeyboardInterrupt, SystemExit,
#     306     # and GeneratorExit
#     307     except Exception as exc:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\widgets.py:1497, in TextBox._keypress(self, event)
#    1495 self._observers.process('change', self.text)
#    1496 if key in ["enter", "return"]:
# -> 1497     self._observers.process('submit', self.text)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:309, in CallbackRegistry.process(self, s, *args, **kwargs)
#     307 except Exception as exc:
#     308     if self.exception_handler is not None:
# --> 309         self.exception_handler(exc)
#     310     else:
#     311         raise
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:96, in _exception_printer(exc)
#      94 def _exception_printer(exc):
#      95     if _get_running_interactive_framework() in ["headless", None]:
# ---> 96         raise exc
#      97     else:
#      98         traceback.print_exc()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\cbook\__init__.py:304, in CallbackRegistry.process(self, s, *args, **kwargs)
#     302 if func is not None:
#     303     try:
# --> 304         func(*args, **kwargs)
#     305     # this does not capture KeyboardInterrupt, SystemExit,
#     306     # and GeneratorExit
#     307     except Exception as exc:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\widgets.py:1588, in TextBox.on_submit.<locals>.<lambda>(text)
#    1581 def on_submit(self, func):
#    1582     """
#    1583     When the user hits enter or leaves the submission box, call this
#    1584     *func* with event.
#    1585
#    1586     A connection id is returned which can be used to disconnect.
#    1587     """
# -> 1588     return self._observers.connect('submit', lambda text: func(text))
#
# d:\.MedProject\healthapp\matplot_widget.ipynb Cell 3 in 1
#       <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> def submit(expression):
#       <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a>     """
#       <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a>     Update the plotted function to the new math *expression*.
#      <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a>     """
# ---> <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a>     ydata = eval(expression)
#      <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a>     l.set_ydata(ydata)
#      <a href='vscode-notebook-cell:/d%3A/.MedProject/healthapp/matplot_widget.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a>     ax.relim()
#
# File <string>:1
#
# NameError: name 'b' is not defined
#   File <string>:1
#     np.sin(x**3
#           ^
# SyntaxError: '(' was never closed
# <string>:1: RuntimeWarning: invalid value encountered in sqrt
# <string>:1: RuntimeWarning: invalid value encountered in sqrt
# <string>:1: RuntimeWarning: invalid value encountered in power
# <string>:1: RuntimeWarning: invalid value encountered in power
# <string>:1: RuntimeWarning: invalid value encountered in power
# <string>:1: RuntimeWarning: invalid value encountered in power
# <string>:1: RuntimeWarning: invalid value encountered in power
# <string>:1: RuntimeWarning: invalid value encountered in power
# <string>:1: RuntimeWarning: invalid value encountered in power
#   File <string>:1
#     np.sin(x**0.45)+np.tan(1/2x)
#                              ^
# SyntaxError: invalid decimal literal
#   File <string>:1
#     np.sin(x**0.45)+np.tan(1/0.5x)
#                                ^
# SyntaxError: invalid decimal literal
# <string>:1: RuntimeWarning: invalid value encountered in power
